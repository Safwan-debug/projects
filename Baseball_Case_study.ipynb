# %% [markdown]
# # Baseball Case Study
# **Problem Statement:-**
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Base ball case study.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR  ...   RA   ER   ERA  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  ...  641  601  3.73   2    8  56   88
# 1    83  696  5467  1349  277  44  156  ...  700  653  4.07   2   12  45   86
# 2    81  669  5439  1395  303  29  141  ...  640  584  3.67  11   10  38   79
# 3    76  622  5533  1381  260  27  136  ...  701  643  3.98   7    9  37  101
# 4    74  689  5605  1515  289  49  151  ...  803  746  4.64   7   12  35   86
# 5    93  891  5509  1480  308  17  232  ...  670  609  3.80   7   10  34   88
# 6    87  764  5567  1397  272  19  212  ...  698  652  4.03   3    4  48   93
# 7    81  713  5485  1370  246  20  217  ...  693  646  4.05   0   10  43   77
# 8    80  644  5485  1383  278  32  167  ...  642  604  3.74   1   12  60   95
# 9    78  748  5640  1495  294  33  161  ...  753  694  4.31   3   10  40   97
# 10   88  751  5511  1419  279  32  172  ...  733  680  4.24   5    9  45  119
# ...

# %% [markdown]
# Overall dataset of Baseball Case Study.

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR  ...   RA   ER   ERA  CG  SHO  SV    E
# 0  95  724  5575  1497  300  42  139  ...  641  601  3.73   2    8  56   88
# 1  83  696  5467  1349  277  44  156  ...  700  653  4.07   2   12  45   86
# 2  81  669  5439  1395  303  29  141  ...  640  584  3.67  11   10  38   79
# 3  76  622  5533  1381  260  27  136  ...  701  643  3.98   7    9  37  101
# 4  74  689  5605  1515  289  49  151  ...  803  746  4.64   7   12  35   86
#
# [5 rows x 17 columns]

# %% [markdown]
# First 5 rows of given dataset.

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR  ...   RA   ER   ERA  CG  SHO  SV   E
# 25  92  667  5385  1346  263  26  187  ...  595  553  3.44   6   21  47  75
# 26  84  696  5565  1486  288  39  136  ...  627  597  3.72   7   18  41  78
# 27  79  720  5649  1494  289  48  154  ...  713  659  4.04   1   12  44  86
# 28  74  650  5457  1324  260  36  148  ...  731  655  4.09   1    6  41  92
# 29  68  737  5572  1479  274  49  186  ...  844  799  5.04   4    4  36  95
#
# [5 rows x 17 columns]

# %% [markdown]
# last 5 rows of given dataset.

# %%
df1= df.rename(columns = {'W' : 'Wins', 'R' : 'Runs', 'AB' : 'At Bats', 'H' : 'Hits', '2B' : 'Doubles', '3B' : 'Triples', 'HR' : 'Homeruns', 'BB' : 'Walks', 'SO' : 'Strikeouts', 'SB' : 'Stolen Bases', 'RA' : 'Runs Allowed', 'ER' : 'Earned Runs', 'ERA' : 'Earned Run Average', 'SHO' : 'Shutouts', 'SV' : 'Saves', 'E' : 'Errors',}, inplace = False)

# %% [markdown]
# Based on our requirement we change the columns names

# %%
df1
# Out:
#     Wins  Runs  At Bats  Hits  ...  CG  Shutouts  Saves  Errors
# 0     95   724     5575  1497  ...   2         8     56      88
# 1     83   696     5467  1349  ...   2        12     45      86
# 2     81   669     5439  1395  ...  11        10     38      79
# 3     76   622     5533  1381  ...   7         9     37     101
# 4     74   689     5605  1515  ...   7        12     35      86
# 5     93   891     5509  1480  ...   7        10     34      88
# 6     87   764     5567  1397  ...   3         4     48      93
# 7     81   713     5485  1370  ...   0        10     43      77
# 8     80   644     5485  1383  ...   1        12     60      95
# 9     78   748     5640  1495  ...   3        10     40      97
# 10    88   751     5511  1419  ...   5         9     45     119
# 11    86   729     5459  1363  ...   5        13     39      85
# 12    85   661     5417  1331  ...   2        12     46      93
# 13    76   656     5544  1379  ...   6        12     45      94
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wins                30 non-null     int64
#  1   Runs                30 non-null     int64
#  2   At Bats             30 non-null     int64
#  3   Hits                30 non-null     int64
#  4   Doubles             30 non-null     int64
#  5   Triples             30 non-null     int64
#  6   Homeruns            30 non-null     int64
#  7   Walks               30 non-null     int64
#  8   Strikeouts          30 non-null     int64
#  9   Stolen Bases        30 non-null     int64
#  10  Runs Allowed        30 non-null     int64
#  11  Earned Runs         30 non-null     int64
#  12  Earned Run Average  30 non-null     float64
#  13  CG                  30 non-null     int64
#  14  Shutouts            30 non-null     int64
#  15  Saves               30 non-null     int64
# ...

# %%
df1.describe()
# Out:
#              Wins        Runs      At Bats  ...   Shutouts      Saves      Errors
# count   30.000000   30.000000    30.000000  ...  30.000000  30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  ...  11.300000  43.066667   94.333333
# std     10.453455   58.761754    70.467372  ...   4.120177   7.869335   13.958889
# min     63.000000  573.000000  5385.000000  ...   4.000000  28.000000   75.000000
# 25%     74.000000  651.250000  5464.000000  ...   9.000000  37.250000   86.000000
# 50%     81.000000  689.000000  5510.000000  ...  12.000000  42.000000   91.000000
# 75%     87.750000  718.250000  5570.000000  ...  13.000000  46.750000   96.750000
# max    100.000000  891.000000  5649.000000  ...  21.000000  62.000000  126.000000
#
# [8 rows x 17 columns]

# %% [markdown]
# Statistical information of Dataset
#
# Except Earned run Average and CG,all other columns have higher mean and standard Deviation. Given data is not standard and uneven.It can be regularized later for the model to understand it better.

# %%
df1.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns

# %% [markdown]
# ## Data Visualisations

# %%
df1.isnull().sum()
# Out:
# Wins                  0
# Runs                  0
# At Bats               0
# Hits                  0
# Doubles               0
# Triples               0
# Homeruns              0
# Walks                 0
# Strikeouts            0
# Stolen Bases          0
# Runs Allowed          0
# Earned Runs           0
# Earned Run Average    0
# CG                    0
# Shutouts              0
# Saves                 0
# Errors                0
# dtype: int64

# %%
sns.heatmap(df1.isnull())

# %% [markdown]
# we can see here there is no null values in the given dataset

# %%
fig=plt.figure(figsize=(12,8))
hf=df.corr(method ='pearson')
sns.heatmap(hf,annot=True,cmap='Reds')

# %% [markdown]
# Here we see the correlation plot of each of the columns

# %%
sns.distplot(df1['At Bats'])

# %%
df1.columns
# Out:
# Index(['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
#        'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
#        'Earned Run Average', 'CG', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %%
columns=['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
       'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
       'Earned Run Average', 'CG', 'Shutouts', 'Saves', 'Errors']
for i in df1[columns]:
    plt.figure()
    sns.distplot(df1[i])

# %%
columns=['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
       'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
       'Earned Run Average', 'CG', 'Shutouts', 'Saves', 'Errors']
for i in df1[columns]:
    plt.figure()
    sns.countplot(df1[i])

# %%
sns.pairplot(df1)

# %%
df1.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(10,8))
plt.show()

# %% [markdown]
# From this density plot curve we see only some skewness in few graphs

# %%
plt.figure(figsize = (15,20))
df1.corr()['Wins'].sort_values(ascending = False).drop(['Wins']).plot(kind = 'bar', color = 'c')
plt.xlabel('Input Features', fontsize = 15)
plt.ylabel('columns with Target Names', fontsize = 15)
plt.title('Correlation', fontsize = 20)
plt.show()

# %% [markdown]
# *The above figure shows the column wise correlation with target. 2.There is a high possibility of outliers presence, it shall be seen with help of Boxplot.*

# %% [markdown]
# ## Checking Outliers

# %%
df1.plot(kind='box',subplots=True,layout=(1,17),figsize=[20,8])
plt.show()

# %% [markdown]
# Boxplot seems like there are some outliers i.e Runs,Earned Run Average,Shutouts,Saves and errors. They have little outliers that can be ignored.

# %%
df1.skew()
# Out:
# Wins                  0.047089
# Runs                  1.200786
# At Bats               0.183437
# Hits                  0.670254
# Doubles              -0.230650
# Triples               0.129502
# Homeruns              0.516441
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen Bases          0.479893
# Runs Allowed          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# CG                    0.736845
# Shutouts              0.565790
# Saves                 0.657524
# Errors                0.890132
# dtype: float64

# %% [markdown]
# *Outliers are hardly seen to be affecting the target. We can clearly visualized the data by using Histogram plotting i.e distplot. Since it show, if any skewwness.*

# %%
df1_hist = df1.columns.values
plt.figure(figsize = (8,14))
for i in range (0, len(df1_hist)):
    sns.distplot(df1[df1_hist[i]], color = 'maroon')
    plt.show()

# %% [markdown]
# 1.Distplot shows there is No Skewwness. 2.given data is not skewwed and don't have outliers. 3.The Target is clearly continous type.It should dealt with linear regression while testing the model. 4.Data is not normal as it has irregular mean and standard deviation.

# %%
df1.describe().T
# Out:
#                     count         mean         std  ...       50%      75%      max
# Wins                 30.0    80.966667   10.453455  ...    81.000    87.75   100.00
# Runs                 30.0   688.233333   58.761754  ...   689.000   718.25   891.00
# At Bats              30.0  5516.266667   70.467372  ...  5510.000  5570.00  5649.00
# Hits                 30.0  1403.533333   57.140923  ...  1382.500  1451.50  1515.00
# Doubles              30.0   274.733333   18.095405  ...   275.500   288.75   308.00
# Triples              30.0    31.300000   10.452355  ...    31.000    39.00    49.00
# Homeruns             30.0   163.633333   31.823309  ...   158.500   177.00   232.00
# Walks                30.0   469.100000   57.053725  ...   473.000   501.25   570.00
# Strikeouts           30.0  1248.200000  103.759470  ...  1261.500  1311.50  1518.00
# Stolen Bases         30.0    83.500000   22.815225  ...    83.500    96.50   134.00
# ...

# %% [markdown]
# ## Lets split the data and then independent variables are to be normalized.

# %%
x = df1.iloc[:,1:]
y = df1.iloc[:,0]

# %%
x
# Out:
#     Runs  At Bats  Hits  Doubles  ...  CG  Shutouts  Saves  Errors
# 0    724     5575  1497      300  ...   2         8     56      88
# 1    696     5467  1349      277  ...   2        12     45      86
# 2    669     5439  1395      303  ...  11        10     38      79
# 3    622     5533  1381      260  ...   7         9     37     101
# 4    689     5605  1515      289  ...   7        12     35      86
# 5    891     5509  1480      308  ...   7        10     34      88
# 6    764     5567  1397      272  ...   3         4     48      93
# 7    713     5485  1370      246  ...   0        10     43      77
# 8    644     5485  1383      278  ...   1        12     60      95
# 9    748     5640  1495      294  ...   3        10     40      97
# 10   751     5511  1419      279  ...   5         9     45     119
# 11   729     5459  1363      278  ...   5        13     39      85
# 12   661     5417  1331      243  ...   2        12     46      93
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: Wins, dtype: int64

# %%
y = y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (30, 1)

# %%
x.skew()
# Out:
# Runs                  1.200786
# At Bats               0.183437
# Hits                  0.670254
# Doubles              -0.230650
# Triples               0.129502
# Homeruns              0.516441
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen Bases          0.479893
# Runs Allowed          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# CG                    0.736845
# Shutouts              0.565790
# Saves                 0.657524
# Errors                0.890132
# dtype: float64

# %%
for index in x.skew().index:
    if x.skew().loc[index]>0.5:
        x[index]=np.log1p(x[index])
    if x.skew().loc[index]<-0.5:
        x[index]=np.square(x[index])

# %% [markdown]
# Let's take the threshold skewwness to be 0.5
# LLog transformation is applied to remove the skewwness

# %%
x.skew()
# Out:
# Runs                  0.744813
# At Bats               0.183437
# Hits                  0.628584
# Doubles              -0.230650
# Triples               0.129502
# Homeruns             -0.009528
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen Bases          0.479893
# Runs Allowed          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# CG                   -0.325962
# Shutouts             -0.093545
# Saves                 0.163057
# Errors                0.632916
# dtype: float64

# %% [markdown]
# Skewness is Removed

# %%
x
# Out:
#         Runs  At Bats      Hits  ...  Shutouts     Saves    Errors
# 0   6.586172     5575  7.311886  ...  4.827796  4.043051  4.488636
# 1   6.546785     5467  7.207860  ...  6.578965  3.828641  4.465908
# 2   6.507278     5439  7.241366  ...  5.749902  3.663562  4.382027
# 3   6.434547     5533  7.231287  ...  5.301898  3.637586  4.624973
# 4   6.536692     5605  7.323831  ...  6.578965  3.583519  4.465908
# 5   6.793466     5509  7.300473  ...  5.749902  3.555348  4.488636
# 6   6.639876     5567  7.242798  ...  2.590290  3.891820  4.543295
# 7   6.570883     5485  7.223296  ...  5.749902  3.784190  4.356709
# 8   6.469250     5485  7.232733  ...  6.578965  4.110874  4.564348
# 9   6.618739     5640  7.310550  ...  5.749902  3.713572  4.584967
# 10  6.622736     5511  7.258412  ...  5.301898  3.828641  4.787492
# 11  6.593045     5459  7.218177  ...  6.964624  3.688879  4.454347
# 12  6.495266     5417  7.194437  ...  6.578965  3.850148  4.543295
# ...

# %% [markdown]
# Standard scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
pd.DataFrame(x)
# Out:
#           0         1         2   ...        13        14        15
# 0   0.665329  0.847731  1.649382  ... -0.789565  1.581273 -0.427060
# 1   0.179562 -0.711094 -0.981656  ...  0.267953  0.336185 -0.591693
# 2  -0.307704 -1.115233 -0.134210  ... -0.232712 -0.622441 -1.199289
# 3  -1.204730  0.241522 -0.389136  ... -0.503258 -0.773282  0.560495
# 4   0.055070  1.280738  1.951480  ...  0.267953 -1.087253 -0.591693
# 5   3.221983 -0.104884  1.360715  ... -0.232712 -1.250843 -0.427060
# 6   1.327687  0.732263 -0.098001  ... -2.140778  0.703068 -0.031141
# 7   0.476767 -0.451289 -0.591253  ... -0.232712  0.078051 -1.382679
# 8  -0.776713 -0.451289 -0.352560  ...  0.267953  1.975123  0.121359
# 9   1.066997  1.785913  1.615591  ... -0.232712 -0.332028  0.270716
# 10  1.116298 -0.076017  0.296915  ... -0.503258  0.336185  1.737703
# 11  0.750096 -0.826562 -0.720719  ...  0.500849 -0.475419 -0.675434
# 12 -0.455855 -1.432772 -1.321151  ...  0.267953  0.461073 -0.031141
# ...

# %% [markdown]
# Standard Scaler has brought the data into single scale where it is easy to the model to understand the data.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

# %%
lr = LinearRegression()
for i in range(0,1000):
    x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train, y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    if round(mean_absolute_error(pred_train, y_train)*100,1) == round(mean_absolute_error(pred_test, y_test)*100,1):
        print('at random state', i, 'The model performs well')
        print('at random state', i)
        print('training socre is:', mean_absolute_error(pred_train, y_train)*100)
        print('testing score is:', mean_absolute_error(pred_test, y_test)*100)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=50,test_size=0.20)

# %%
x_test.shape
# Out:
# (6, 16)

# %%
x_train.shape
# Out:
# (24, 16)

# %%
y_test.shape
# Out:
# (6, 1)

# %%
y_train.shape
# Out:
# (24, 1)

# %%
le = LinearRegression()
m1 = le.fit(x_train, y_train)
pred = le.predict(x_test)
mae = mean_absolute_error(pred,y_test)
print('Mean Absolute Error:', round(mae,1))
# Out:
# Mean Absolute Error: 5.1

# %%
le.score(x_train,y_train)
# Out:
# 0.9840021355658375

# %%
r2 = r2_score(pred, y_test)
print(r2)
# Out:
# 0.511016677490661

# %%
from sklearn.model_selection import cross_val_score
le_cross = cross_val_score(LinearRegression(), x, y, cv = 5)
print(le_cross)
print(le_cross.mean()*100, le_cross.std())
# Out:
# [ 0.69348027 -3.03388939  0.57756892  0.67596651  0.24924174]
# -16.752638840055145 1.4420618767871802

# %%
from sklearn.linear_model import Lasso,Ridge
ls = Lasso(alpha = 0.0001)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
# Out:
# 0.9796228541958887

# %%
from sklearn.linear_model import ElasticNet
enr = ElasticNet(alpha = 0.0001)
enr.fit(x_train, y_train)
enr_pred = enr.predict(x_test)
enr.score(x_train, y_train)
# Out:
# 0.9795876943098423

# %% [markdown]
# ELasticNet is a combination of both Lasso and Ridge

# %%
from sklearn.ensemble import RandomForestRegressor
regressor1 = RandomForestRegressor(n_estimators= 100)
regressor1.fit(x_train,y_train)
print('Train score',regressor1.score(x_train,y_train))
print('Test score',regressor1.score(x_test,y_test))
# Out:
# Train score 0.9268704890387858
# Test score 0.6480912534263644

# %% [markdown]
#  **Random Forest Regressor seems to have better score.**
