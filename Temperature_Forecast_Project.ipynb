# %% [markdown]
# # Temperature Forecast Project using ML
#
# ***Problem Statement:-***
#
# Data Set Information:-
#
# This data is for the purpose of bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model operated by the Korea Meteorological Administration over Seoul, South Korea. This data consists of summer data from 2013 to 2017. The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum air temperatures) in this data. Hindcast validation was conducted for the period from 2015 to 2017.
#
#
# Attribute Information:
#
# For more information, read [Cho et al, 2020].
# 1. station - used weather station number: 1 to 25
# 2. Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')
# 3. Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6
# 4. Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9
# 5. LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5
# 6. LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100
# 7. LDAPS_Tmax_lapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5
# 8. LDAPS_Tmin_lapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6
# 9. LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9
# 10. LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4
# 11. LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97
# 12. LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97
# 13. LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98
# 14. LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97
# 15. LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7
# 16. LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6
# 17. LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8
# 18. LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7
# 19. lat - Latitude (Â°): 37.456 to 37.645
# 20. lon - Longitude (Â°): 126.826 to 127.135
# 21. DEM - Elevation (m): 12.4 to 212.3
# 22. Slope - Slope (Â°): 0.1 to 5.2
# 23. Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9
# 24. Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9
# 25. Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T
#
# Please note that there are two target variables here:-
#
# 1) Next_Tmax: Next day maximum temperature
#
# 2) Next_Tmin: Next day minimum temperature

# %% [markdown]
# ## Importing the required libraries

# %%
import pandas as pd
import numpy as np

#for plotting and EDA
import seaborn as sns
import matplotlib.pyplot as plt

#for spliting dataset into train and test
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV,RandomizedSearchCV

#for model building
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

#for model evaluation
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

from sklearn.preprocessing import MinMaxScaler,power_transform,LabelEncoder,OrdinalEncoder,StandardScaler
from sklearn.decomposition import PCA

from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
#displaying maximum columns
pd.set_option('display.max_columns',None)

#there is column called date, so we are using parse date for that column
df = pd.read_csv('/content/Temparature forecast project.csv',parse_dates= ['Date'])

# %%
df.head()
# Out:
#    station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0 2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0 2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0 2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0 2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947
# 1         29.850689         24.035009  5.691890   51.937448   0.225508
# 2         30.091292         24.565633  6.138224   20.573050   0.209344
# 3         29.704629         23.326177  5.650050   65.727144   0.216372
# 4         29.113934         23.486480  5.735004  107.965535   0.151407
#
#    LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0   0.203896   0.161697   0.130928         0.0         0.0         0.0
# 1   0.251771   0.159444   0.127727         0.0         0.0         0.0
# 2   0.257469   0.204091   0.142125         0.0         0.0         0.0
# 3   0.226002   0.161157   0.134249         0.0         0.0         0.0
# 4   0.249995   0.178892   0.170021         0.0         0.0         0.0
#
#    LDAPS_PPT4      lat      lon       DEM   Slope  Solar radiation  Next_Tmax  \
# 0         0.0  37.6046  126.991  212.3350  2.7850      5992.895996       29.1
# 1         0.0  37.6046  127.032   44.7624  0.5141      5869.312500       30.5
# 2         0.0  37.5776  127.058   33.3068  0.2661      5863.555664       31.1
# 3         0.0  37.6450  127.022   45.7160  2.5348      5856.964844       31.7
# 4         0.0  37.5507  127.135   35.0380  0.5055      5859.552246       31.2
#
#    Next_Tmin
# 0       21.2
# 1       22.5
# 2       23.9
# 3       24.3
# 4       22.5

# %% [markdown]
# ## checking shape

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# There are 7752 rows 25 columns including 2 target columns.

# %% [markdown]
# ## checking columns

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %% [markdown]
# Please note that there are two target variables here :-
#
# 1) Next_Tmax: Next day maximum temperature .
#
# 2) Next_Tmin: Next day minimum temperature .

# %% [markdown]
# ## checking datatypes

# %%
df.dtypes
# Out:
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# Next_Tmax                  float64
# Next_Tmin                  float64
# dtype: object

# %% [markdown]
# We can see that all the columns are float datatype , date column is date datetype .

# %% [markdown]
# ## Checking Null values

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# we can see that most of the columns are having null values.

# %% [markdown]
# ## Statistical information

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.673499         22.089739     5.678705    37.266753
# 50%           29.703426         23.760199     6.547470    56.865482
# 75%           31.710450         25.152909     8.032276    84.223616
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1    LDAPS_CC2    LDAPS_CC3    LDAPS_CC4   LDAPS_PPT1  \
# count  7677.000000  7677.000000  7677.000000  7677.000000  7677.000000
# mean      0.368774     0.356080     0.318404     0.299191     0.591995
# std       0.262458     0.258061     0.250362     0.254348     1.945768
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.146654     0.140615     0.101388     0.081532     0.000000
# 50%       0.315697     0.312421     0.262555     0.227664     0.000000
# 75%       0.575489     0.558694     0.496703     0.499489     0.052525
# max       0.967277     0.968353     0.983789     0.974710    23.701544
#
#         LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat          lon  \
# count  7677.000000  7677.000000  7677.000000  7752.000000  7752.000000
# mean      0.485003     0.278200     0.269407    37.544722   126.991397
# std       1.762807     1.161809     1.206214     0.050352     0.079435
# min       0.000000     0.000000     0.000000    37.456200   126.826000
# 25%       0.000000     0.000000     0.000000    37.510200   126.937000
# 50%       0.000000     0.000000     0.000000    37.550700   126.995000
# 75%       0.018364     0.007896     0.000041    37.577600   127.042000
# max      21.621661    15.841235    16.655469    37.645000   127.135000
#
#                DEM        Slope  Solar radiation    Next_Tmax    Next_Tmin
# count  7752.000000  7752.000000      7752.000000  7725.000000  7725.000000
# mean     61.867972     1.257048      5341.502803    30.274887    22.932220
# std      54.279780     1.370444       429.158867     3.128010     2.487613
# min      12.370000     0.098475      4329.520508    17.400000    11.300000
# 25%      28.700000     0.271300      4999.018555    28.200000    21.300000
# 50%      45.716000     0.618000      5436.345215    30.500000    23.100000
# 75%      59.832400     1.767800      5728.316406    32.600000    24.600000
# max     212.335000     5.178230      5992.895996    38.900000    29.800000

# %% [markdown]
# 1) LDAPS_RHmax,LDAPS_Tmin_lapse, Solar radiation, LDAPS_WS, LDAPS_LH, LDAPS_CC3, LDAPS_CC4, LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3, LDAPS_PPT4, DEM and Slope have skewness becuase their mean and std have too much difference.
#
# 2) LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3 and LDAPS_PPT4 have too many outlier because their 75% and max value have too much difference.

# %% [markdown]
# ## Checking Correlation

# %%
#lets check for correlation among all the columns
df.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# DEM                 0.011345    0.008397    0.017270   -0.003640  0.033165
# Slope               0.016389    0.010264    0.025456    0.000118  0.074763
# Solar radiation     0.088273    0.110505   -0.054229    0.035060  0.038513
# Next_Tmax          -0.120079   -0.180449   -0.196845   -0.180669 -0.053567
# Next_Tmin           0.021486   -0.008131   -0.063318   -0.104515 -0.083621
#
#                        lon       DEM     Slope  Solar radiation  Next_Tmax  \
# station          -0.118763 -0.255970 -0.090113        -0.019011   0.108306
# Present_Tmax      0.009075 -0.187855 -0.106097        -0.025557   0.613109
# Present_Tmin     -0.043725 -0.251257 -0.146736         0.053828   0.473868
# LDAPS_RHmin      -0.076608  0.102612  0.124346         0.244795  -0.442958
# LDAPS_RHmax       0.025792  0.178031  0.220668         0.149699  -0.286478
# LDAPS_Tmax_lapse  0.091107 -0.179766 -0.163123         0.048111   0.836144
# LDAPS_Tmin_lapse -0.026831 -0.196407 -0.186753         0.160443   0.593195
# LDAPS_WS         -0.059756  0.191983  0.172464         0.122116  -0.346592
# LDAPS_LH          0.025948  0.055402  0.087203        -0.047523   0.159324
# LDAPS_CC1        -0.006876 -0.014159 -0.020853         0.218949  -0.457583
# LDAPS_CC2        -0.003599 -0.012886 -0.018161         0.170903  -0.496251
# LDAPS_CC3         0.016119  0.000701 -0.003355         0.119642  -0.520706
# LDAPS_CC4        -0.002489 -0.007370 -0.014530         0.120335  -0.451324
# LDAPS_PPT1       -0.001231  0.011345  0.016389         0.088273  -0.120079
# LDAPS_PPT2        0.018690  0.008397  0.010264         0.110505  -0.180449
# LDAPS_PPT3        0.021767  0.017270  0.025456        -0.054229  -0.196845
# LDAPS_PPT4        0.044963 -0.003640  0.000118         0.035060  -0.180669
# lat               0.289029  0.033165  0.074763         0.038513  -0.053567
# lon               1.000000  0.007587  0.038070         0.002182   0.003060
# DEM               0.007587  1.000000  0.783576         0.056224  -0.172674
# Slope             0.038070  0.783576  1.000000         0.028199  -0.102838
# Solar radiation   0.002182  0.056224  0.028199         1.000000   0.008809
# Next_Tmax         0.003060 -0.172674 -0.102838         0.008809   1.000000
# Next_Tmin        -0.046737 -0.247100 -0.147043         0.120400   0.621427
#
#                   Next_Tmin
# station            0.128719
# Present_Tmax       0.625252
# Present_Tmin       0.799758
# LDAPS_RHmin        0.095830
# LDAPS_RHmax       -0.072490
# LDAPS_Tmax_lapse   0.591535
# LDAPS_Tmin_lapse   0.886964
# LDAPS_WS          -0.097390
# LDAPS_LH          -0.055895
# LDAPS_CC1         -0.011129
# LDAPS_CC2          0.031500
# LDAPS_CC3         -0.055217
# LDAPS_CC4         -0.085805
# LDAPS_PPT1         0.021486
# LDAPS_PPT2        -0.008131
# LDAPS_PPT3        -0.063318
# LDAPS_PPT4        -0.104515
# lat               -0.083621
# lon               -0.046737
# DEM               -0.247100
# Slope             -0.147043
# Solar radiation    0.120400
# Next_Tmax          0.621427
# Next_Tmin          1.000000

# %%
fig = plt.figure(figsize=(25,15))
cor_matrix = df.corr(method='pearson')
sns.heatmap(cor_matrix,annot = True,cmap = 'YlGnBu')
plt.show()

# %% [markdown]
# ## lets check for the correlation of input columns with first Target Variable (TMAX)

# %%
cor_matrix['Next_Tmax'].sort_values(ascending = False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.836144
# Next_Tmin           0.621427
# Present_Tmax        0.613109
# LDAPS_Tmin_lapse    0.593195
# Present_Tmin        0.473868
# LDAPS_LH            0.159324
# station             0.108306
# Solar radiation     0.008809
# lon                 0.003060
# lat                -0.053567
# Slope              -0.102838
# LDAPS_PPT1         -0.120079
# DEM                -0.172674
# LDAPS_PPT2         -0.180449
# LDAPS_PPT4         -0.180669
# LDAPS_PPT3         -0.196845
# LDAPS_RHmax        -0.286478
# LDAPS_WS           -0.346592
# LDAPS_RHmin        -0.442958
# LDAPS_CC4          -0.451324
# LDAPS_CC1          -0.457583
# LDAPS_CC2          -0.496251
# LDAPS_CC3          -0.520706
# Name: Next_Tmax, dtype: float64

# %% [markdown]
# Next_Tmax is highly positively correlated with LDAPS_Tmax_lapse and highly negatively correlated with LDAPS_CC3.

# %% [markdown]
# ## lets check for the correlation of input columns with Second Target Variable (TMIN)

# %%
cor_matrix['Next_Tmin'].sort_values(ascending = False)
# Out:
# Next_Tmin           1.000000
# LDAPS_Tmin_lapse    0.886964
# Present_Tmin        0.799758
# Present_Tmax        0.625252
# Next_Tmax           0.621427
# LDAPS_Tmax_lapse    0.591535
# station             0.128719
# Solar radiation     0.120400
# LDAPS_RHmin         0.095830
# LDAPS_CC2           0.031500
# LDAPS_PPT1          0.021486
# LDAPS_PPT2         -0.008131
# LDAPS_CC1          -0.011129
# lon                -0.046737
# LDAPS_CC3          -0.055217
# LDAPS_LH           -0.055895
# LDAPS_PPT3         -0.063318
# LDAPS_RHmax        -0.072490
# lat                -0.083621
# LDAPS_CC4          -0.085805
# LDAPS_WS           -0.097390
# LDAPS_PPT4         -0.104515
# Slope              -0.147043
# DEM                -0.247100
# Name: Next_Tmin, dtype: float64

# %% [markdown]
# Next_Tmin is highly positively correlated with LDAPS_Tmax_lapse.

# %% [markdown]
# ## Data PreProcessing

# %% [markdown]
# Handling the Null values in the dataset

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# we can see that all the belows column are null for the same rows.

# %%
df.loc[df.LDAPS_RHmin.isnull()]
# Out:
#       station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 1025      1.0 2013-10-08          27.1          24.5          NaN
# 1026      2.0 2013-10-08          29.7          25.4          NaN
# 1027      3.0 2013-10-08          29.1          25.9          NaN
# 1028      4.0 2013-10-08          30.8          27.3          NaN
# 1029      5.0 2013-10-08          29.7          25.7          NaN
# ...       ...        ...           ...           ...          ...
# 5945     21.0 2016-08-20          34.1          27.9          NaN
# 5946     22.0 2016-08-20          34.3          27.7          NaN
# 5947     23.0 2016-08-20          34.6          28.7          NaN
# 5948     24.0 2016-08-20          35.0          28.6          NaN
# 5949     25.0 2016-08-20          35.2          28.1          NaN
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  \
# 1025          NaN               NaN               NaN       NaN       NaN
# 1026          NaN               NaN               NaN       NaN       NaN
# 1027          NaN               NaN               NaN       NaN       NaN
# 1028          NaN               NaN               NaN       NaN       NaN
# 1029          NaN               NaN               NaN       NaN       NaN
# ...           ...               ...               ...       ...       ...
# 5945          NaN               NaN               NaN       NaN       NaN
# 5946          NaN               NaN               NaN       NaN       NaN
# 5947          NaN               NaN               NaN       NaN       NaN
# 5948          NaN               NaN               NaN       NaN       NaN
# 5949          NaN               NaN               NaN       NaN       NaN
#
#       LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  \
# 1025        NaN        NaN        NaN        NaN         NaN         NaN
# 1026        NaN        NaN        NaN        NaN         NaN         NaN
# 1027        NaN        NaN        NaN        NaN         NaN         NaN
# 1028        NaN        NaN        NaN        NaN         NaN         NaN
# 1029        NaN        NaN        NaN        NaN         NaN         NaN
# ...         ...        ...        ...        ...         ...         ...
# 5945        NaN        NaN        NaN        NaN         NaN         NaN
# 5946        NaN        NaN        NaN        NaN         NaN         NaN
# 5947        NaN        NaN        NaN        NaN         NaN         NaN
# 5948        NaN        NaN        NaN        NaN         NaN         NaN
# 5949        NaN        NaN        NaN        NaN         NaN         NaN
#
#       LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 1025         NaN         NaN  37.6046  126.991  212.3350  2.7850
# 1026         NaN         NaN  37.6046  127.032   44.7624  0.5141
# 1027         NaN         NaN  37.5776  127.058   33.3068  0.2661
# 1028         NaN         NaN  37.6450  127.022   45.7160  2.5348
# 1029         NaN         NaN  37.5507  127.135   35.0380  0.5055
# ...          ...         ...      ...      ...       ...     ...
# 5945         NaN         NaN  37.5507  127.040   26.2980  0.5721
# 5946         NaN         NaN  37.5102  127.086   21.9668  0.1332
# 5947         NaN         NaN  37.5372  126.891   15.5876  0.1554
# 5948         NaN         NaN  37.5237  126.909   17.2956  0.2223
# 5949         NaN         NaN  37.5237  126.970   19.5844  0.2713
#
#       Solar radiation  Next_Tmax  Next_Tmin
# 1025      5304.412598       31.4       22.3
# 1026      5162.595703       34.3       23.2
# 1027      5157.235352       33.9       24.0
# 1028      5148.043945       34.9       24.5
# 1029      5147.667969       32.9       23.3
# ...               ...        ...        ...
# 5945      4795.120117       35.5       27.5
# 5946      4782.181641       36.2       27.5
# 5947      4783.152832       37.3       28.8
# 5948      4778.877930       37.0       28.7
# 5949      4790.469727       36.7       28.0
#
# [75 rows x 25 columns]

# %% [markdown]
# Since all the columns are numerical, Before replacing the outliers we need check for the following citeria:-
#
# 1) If column is normal distribued ------> Lets Replace it with Mean of that
# columm.
#
# 2) If column is not normal distribued ------> Lets Replace it with Median of that columm.

# %% [markdown]
# ## lets check the distribution of this column

# %%
df.Present_Tmax.plot.hist()
plt.show()

# %% [markdown]
# column is normal distributed so lets replace outliers with mean.

# %%
#Above column is normal distributed so lets replace outliers with mean
df['Present_Tmax'].fillna(df['Present_Tmax'].mean(),inplace= True)

# %%
#lets check the distribution of this column
df.Present_Tmin.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['Present_Tmin'].fillna(df['Present_Tmin'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_RHmin.plot.hist()
plt.show()

# %%
# Above column is normal distributed so lets replace outliers with mean
df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].mean(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_RHmax.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_Tmax_lapse.plot.hist()
plt.show()

# %%
# Above column is normal distributed so lets replace outliers with mean
df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].mean(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_Tmin_lapse.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_WS.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_WS'].fillna(df['LDAPS_WS'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_LH.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_LH'].fillna(df['LDAPS_LH'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_CC1.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_CC2.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_CC3.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_CC4.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_PPT1.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_PPT2.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_PPT3.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.LDAPS_PPT4.plot.hist()
plt.show()

# %%
# Above column is not normal distributed so lets replace outliers with median
df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].median(),inplace= True)

# %%
#lets check the distribution of this column
df.Next_Tmax.plot.hist()
plt.show()

# %%
# Above column is normal distributed so lets replace outliers with mean
df['Next_Tmax'].fillna(df['Next_Tmax'].mean(),inplace= True)

# %%
#lets check the distribution of this column
df.Next_Tmin.plot.hist()
plt.show()

# %%
# Above column is  almost normal distributed so lets replace outliers with mean
df['Next_Tmin'].fillna(df['Next_Tmin'].mean(),inplace= True)

# %%
#lets check for null values now
for i in df.columns:
    if df[i].isnull().sum() > 1:
        print(i,df[i].isnull().sum())
# Out:
# station 2
# Date 2

# %%
station_mode = df['station'].mode()[0]
station_mode
# Out:
# 1.0

# %% [markdown]
# observations :-
#
# 1) still we have two null values for each of the two columns columns
# station column should be converted to  object datatype, since stattion is not numerical value
# so for station column, we can replace null values with mean or median, it has to replaced with mode .

# %%
station_mode = df['station'].mode()[0]
df['station'] = df['station'].replace(np.nan,station_mode)

# %%
df.station.isnull().sum()
# Out:
# 0

# %% [markdown]
# observations :-
#
# 1) For date column since we have only two rows which is less than 0.01 percent
# if there were many null values in this column, we could have extracted mode of date, month and year
# we can drop the rows with null values .

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# now there are no null values in this dataset .

# %%
df.shape
# Out:
# (7750, 25)

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# 1) Lets Extract the month from the date column, since the temperature  depends on month .
#
# 2) lets also extract the year as well.

# %%
#Changing Date column from object to int for better prediction

import datetime as dt
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].map(dt.datetime.toordinal)
df.head() #Checking top 5 rows of dataset
# Out:
#    station    Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  735049          28.7          21.4    58.255688    91.116364
# 1      2.0  735049          31.9          21.6    52.263397    90.604721
# 2      3.0  735049          31.6          23.3    48.690479    83.973587
# 3      4.0  735049          32.0          23.4    58.239788    96.483688
# 4      5.0  735049          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947
# 1         29.850689         24.035009  5.691890   51.937448   0.225508
# 2         30.091292         24.565633  6.138224   20.573050   0.209344
# 3         29.704629         23.326177  5.650050   65.727144   0.216372
# 4         29.113934         23.486480  5.735004  107.965535   0.151407
#
#    LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0   0.203896   0.161697   0.130928         0.0         0.0         0.0
# 1   0.251771   0.159444   0.127727         0.0         0.0         0.0
# 2   0.257469   0.204091   0.142125         0.0         0.0         0.0
# 3   0.226002   0.161157   0.134249         0.0         0.0         0.0
# 4   0.249995   0.178892   0.170021         0.0         0.0         0.0
#
#    LDAPS_PPT4      lat      lon       DEM   Slope  Solar radiation  Next_Tmax  \
# 0         0.0  37.6046  126.991  212.3350  2.7850      5992.895996       29.1
# 1         0.0  37.6046  127.032   44.7624  0.5141      5869.312500       30.5
# 2         0.0  37.5776  127.058   33.3068  0.2661      5863.555664       31.1
# 3         0.0  37.6450  127.022   45.7160  2.5348      5856.964844       31.7
# 4         0.0  37.5507  127.135   35.0380  0.5055      5859.552246       31.2
#
#    Next_Tmin
# 0       21.2
# 1       22.5
# 2       23.9
# 3       24.3
# 4       22.5

# %%
df.dtypes
# Out:
# station             float64
# Date                  int64
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# # Data Visualization

# %%
#lets check the box plot of our first target column Next_Tmax, to check if there are outliers
sns.boxplot(df.Next_Tmax)
plt.show()

# %% [markdown]
# observations:-
#
# we can see there are outliers in our first target column Next_Tmax.

# %%
#lets check the box plot of our second target column Next_Tmin, to check if there are outliers
sns.boxplot(df.Next_Tmin)
plt.show()

# %% [markdown]
# observations:-
#
# we can see there are outliers in our second target column Next_Tmin.

# %%
#lets check the distribution of our first target column Next_Tmax
sns.distplot(df.Next_Tmax)
plt.show()

# %% [markdown]
# observations :-
#
# Our first target column Next_Tmax is almost normal distributed.

# %%
#lets check the distribution of our Second target column Next_Tmin
sns.distplot(df.Next_Tmin)
plt.show()

# %% [markdown]
# observations :-
#
# Our second target column Next_Tmin is slightly skewed.

# %%
#lets check the violin plot of our First target column Next_Tmax
sns.violinplot(df.Next_Tmax)
plt.show()

# %% [markdown]
# observations :-
#
# The data is distributed between 29 and 33.

# %%
#lets check the violin plot of our Second target column Next_Tmin
sns.violinplot(df.Next_Tmin)
plt.show()

# %% [markdown]
# observations :-
#
# The data is distributed between 20 and 27.

# %% [markdown]
# ## Bivariate Analysis with First Target Variable Next_Tmax

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['Present_Tmax'] )
plt.show()

# %% [markdown]
# observation :-
#
# we can see from below plot , This column is having positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['Present_Tmin'] )
plt.show()

# %% [markdown]
# observation:-
#
# we can see from below plot, This column is having positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['LDAPS_Tmax_lapse'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['LDAPS_Tmin_lapse'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['LDAPS_RHmin'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having slightly negative correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['LDAPS_CC1'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having slightly negative correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['LDAPS_CC2'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having slightly less negative correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['LDAPS_CC3'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having slightly less negative correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmax'] , y =df['LDAPS_CC4'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having slightly less negative correlation with our target variable.

# %%
#Lets check this column againt our target variable
plt.figure(figsize= (15,5))
sns.barplot(x = df['station'] , y =df['Next_Tmax'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see that temperature noted in station 18 is quite high compare to other stations.

# %% [markdown]
# ## Bivariate Analysis with Second Target Variable Next_Tmin

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['Present_Tmax'] )
plt.show()

# %% [markdown]
# observations :-
#
#
# we can see from below plot , This column is having positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['Present_Tmin'] )
plt.show()

# %% [markdown]
# observations :-
#
#
# we can see from below plot , This column is having positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['LDAPS_Tmax_lapse'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['LDAPS_Tmin_lapse'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['LDAPS_RHmin'] )
plt.show()

# %% [markdown]
# observations :-
#
# we can see from below plot , This column is having slightly positive correlation with our target variable.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['LDAPS_CC1'] )
plt.show()

# %% [markdown]
# observation :-
#
# There is less relation between these columns.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['LDAPS_CC2'] )
plt.show()

# %% [markdown]
# observations :-
#
# There is less relation between these columns.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['LDAPS_CC3'] )
plt.show()

# %% [markdown]
# observations :-
#
# There is less relation between these columns.

# %%
#Lets check this column againt our target variable
sns.scatterplot(x = df['Next_Tmin'] , y =df['LDAPS_CC4'] )
plt.show()

# %% [markdown]
# observations :-
#
# There is less relation between these columns.

# %%
#Lets check this column againt our target variable
plt.figure(figsize= (15,5))
sns.barplot(x = df['station'] , y =df['Next_Tmin'] )
plt.show()

# %% [markdown]
# observations :-
#
# Temperature noted in station 1 is quite low compare to other stations.

# %% [markdown]
# ## Checking Outliers

# %%
#lets create a list of numerical columns for outliers removal

Numerical_columns = []
for i in df.columns:
    if df[i].dtype != 'object':
        Numerical_columns.append(i)
Numerical_columns
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %%
# lets check for outliers among all the columns Numerical columns
collist = Numerical_columns
ncol = 3
nrows =9
plt.figure(figsize= (15,5*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='orange',orient = 'v')
    plt.tight_layout()

# %% [markdown]
# **we can see lot of outliers in most of the columns.**

# %% [markdown]
# ## Removing Outliers

# %%
#Function of outlier Removal when data is not normal distributed or Right skewed
def outliers_IQR3(data_frame,feature_name):
    IQR  =data_frame[feature_name].quantile(0.75)-data_frame[feature_name].quantile(0.25)
    lower_boundary = data_frame[feature_name].quantile(0.25) - (IQR * 1.5)
    upper_boundary = data_frame[feature_name].quantile(0.75) + (IQR * 1.5)
    df.loc[df[feature_name] >= upper_boundary,feature_name]= upper_boundary
    df.loc[df[feature_name] <= lower_boundary,feature_name]= lower_boundary

# %%
#calling the function
for i in Numerical_columns:
    outliers_IQR3(df,i)

# %% [markdown]
# observations :-
#
# now the outliers have been removed for all the columns.

# %% [markdown]
# ## Checking skewness

# %%
df.skew()
# Out:
# station             0.000000
# Date               -0.001680
# Present_Tmax       -0.255196
# Present_Tmin       -0.261009
# LDAPS_RHmin         0.300226
# LDAPS_RHmax        -0.738462
# LDAPS_Tmax_lapse   -0.167690
# LDAPS_Tmin_lapse   -0.416531
# LDAPS_WS            0.821395
# LDAPS_LH            0.602904
# LDAPS_CC1           0.464742
# LDAPS_CC2           0.476659
# LDAPS_CC3           0.646029
# LDAPS_CC4           0.673054
# LDAPS_PPT1          1.169549
# LDAPS_PPT2          1.170217
# LDAPS_PPT3          1.175235
# LDAPS_PPT4          0.000000
# lat                 0.086942
# lon                -0.285300
# DEM                 0.729986
# Slope               1.181369
# Solar radiation    -0.511006
# Next_Tmax          -0.302475
# Next_Tmin          -0.286708
# dtype: float64

# %% [markdown]
# ## Splitting the dataset into X, Y1, Y2

# %%
#lets devide X and Y before handing skewness
#Note : we have two target columns in this dataset

Y1 = df['Next_Tmax'] # Y1 is Next_Tmax

Y2 = df['Next_Tmin']  #  Y2is Next_Tmin

X = df.drop(['Next_Tmax','Next_Tmin'],axis = 1)

# %%
#lets create a list of numerical columns in X
Numerical_columns_X = []
for i in X.columns:
    if X[i].dtype != 'object':
        Numerical_columns_X.append(i)

# %%
#Lets check for skewness in numerical columns
X[Numerical_columns_X].skew()
# Out:
# station             0.000000
# Date               -0.001680
# Present_Tmax       -0.255196
# Present_Tmin       -0.261009
# LDAPS_RHmin         0.300226
# LDAPS_RHmax        -0.738462
# LDAPS_Tmax_lapse   -0.167690
# LDAPS_Tmin_lapse   -0.416531
# LDAPS_WS            0.821395
# LDAPS_LH            0.602904
# LDAPS_CC1           0.464742
# LDAPS_CC2           0.476659
# LDAPS_CC3           0.646029
# LDAPS_CC4           0.673054
# LDAPS_PPT1          1.169549
# LDAPS_PPT2          1.170217
# LDAPS_PPT3          1.175235
# LDAPS_PPT4          0.000000
# lat                 0.086942
# lon                -0.285300
# DEM                 0.729986
# Slope               1.181369
# Solar radiation    -0.511006
# dtype: float64

# %% [markdown]
# observations :-
#
# We can see some columns have skewness.

# %% [markdown]
# ## Scaling the Data

# %%
#Lets scale the data using standard scaler
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X),columns= X.columns)
X.head()
# Out:
#     station      Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0 -1.664101 -1.438031     -0.362538     -0.776536     0.102641     0.274164
# 1 -1.525426 -1.438031      0.722162     -0.692021    -0.308235     0.186880
# 2 -1.386750 -1.438031      0.620472      0.026361    -0.553222    -0.779961
# 3 -1.248075 -1.438031      0.756059      0.068618     0.101551     1.315417
# 4 -1.109400 -1.438031      0.552678     -0.565247    -0.040088     0.111787
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  \
# 0         -0.532360         -0.232769  0.082199  0.214722  -0.514235
# 1          0.079109          0.219864 -0.645427 -0.313285  -0.546553
# 2          0.161920          0.453483 -0.335071 -1.258829  -0.608455
# 3          0.028838         -0.092216 -0.676254  0.102434  -0.581540
# 4         -0.174468         -0.021639 -0.613989  1.375798  -0.830324
#
#    LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0  -0.590994  -0.626786  -0.661914   -0.606776   -0.599561   -0.596367
# 1  -0.404515  -0.635831  -0.674562   -0.606776   -0.599561   -0.596367
# 2  -0.382321  -0.456584  -0.617672   -0.606776   -0.599561   -0.596367
# 3  -0.504887  -0.628952  -0.648794   -0.606776   -0.599561   -0.596367
# 4  -0.411433  -0.557751  -0.507451   -0.606776   -0.599561   -0.596367
#
#    LDAPS_PPT4       lat       lon       DEM     Slope  Solar radiation
# 0         0.0  1.189704 -0.005038  1.861259  1.364823         1.518401
# 1         0.0  1.189704  0.511327 -0.206066 -0.567919         1.230307
# 2         0.0  0.653264  0.838778 -0.589472 -0.778990         1.216887
# 3         0.0  1.992377  0.385384 -0.174150  1.151880         1.201522
# 4         0.0  0.118811  1.808536 -0.531531 -0.575239         1.207554

# %%
X.shape
# Out:
# (7750, 23)

# %% [markdown]
# **Now our data is scaled using standard scaler.**

# %% [markdown]
# # Model Selection
#
# We have 2 target columns in dataset:-
#
# 1) Next_Tmax: Next day maximum temperature.
#
# 2) Next_Tmin: Next day minimum temperature.

# %% [markdown]
# ## Best random state with Y1 (Next_Tmax)

# %%
max_r2score_1 = 0
rand_state_1 = 0
for i in range(1,200):
    x_train_1,x_test_1,y_train_1,y_test_1 = train_test_split(X,Y1,test_size=.22,random_state= i )
    lr = LinearRegression()
    lr.fit(x_train_1,y_train_1)
    pred_1 = lr.predict(x_test_1)
    r2_1 = r2_score(y_test_1,pred_1)
    if r2_1 > max_r2score_1:
        max_r2score_1 = r2_1
        rand_state_1 = i
print('Best r2 score is {} on random state {}'.format(max_r2score_1,rand_state_1))
# Out:
# Best r2 score is 0.7872425836595475 on random state 90

# %%
print('We got our best randoms sate as :',rand_state_1)
# Out:
# We got our best randoms sate as : 90

# %%
#Lets split for train and test data
x_train_1,x_test_1,y_train_1,y_test_1 = train_test_split(X,Y1,test_size=.22,random_state= rand_state_1)

# %% [markdown]
# ## Model selection for Y1 (Next_Tmax):

# %%
#checking each model with Cross val score
models=[LinearRegression(),
        SVR(),
        DecisionTreeRegressor(),
        KNeighborsRegressor(),
        RandomForestRegressor(),
        AdaBoostRegressor(),
        GradientBoostingRegressor()]
least_difference_1 = []
for m in models:
    m.fit(x_train_1,y_train_1)
    pred_1 = m.predict(x_test_1)
    cvs = cross_val_score(m,X,Y1,cv =5)
    print('\n')
    print(m)
    print('Scores :')
    print('r2 score:',r2_score(y_test_1,pred_1))
    print('Cross Val score :',cvs.mean())
    print('Error :')
    print('mean absolute error :',mean_absolute_error(y_test_1,pred_1))
    print('mean squared error : ', mean_squared_error(y_test_1,pred_1))
    print('root mean squared error :',np.sqrt(mean_squared_error(y_test_1,pred_1)))
    print('Difference :')
    difference = np.abs(r2_score(y_test_1,pred_1) - cvs.mean())
    print('Diffrence between cross val score and r2 score is : {0:.2f}'.format(difference))
    least_difference_1.append((m,'Diffrence between cross val score and r2 score error is : {0:.2f}'.format(difference)))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Scores :
# r2 score: 0.7872425836595475
# Cross Val score : 0.6660150738651327
# Error :
# mean absolute error : 1.1078495785314324
# mean squared error :  2.1035360031557504
# root mean squared error : 1.4503571984706907
# Difference :
# Diffrence between cross val score and r2 score is : 0.12
#
#
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# Scores :
# r2 score: 0.8869326392560194
# Cross Val score : 0.6580766429127822
# Error :
# mean absolute error : 0.7751884777486291
# mean squared error :  1.1178988173374451
# root mean squared error : 1.0573073428939408
# Difference :
# Diffrence between cross val score and r2 score is : 0.23
#
#
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')
# Scores :
# r2 score: 0.7870039411906777
# Cross Val score : 0.38999375774613976
# Error :
# mean absolute error : 1.0230201292600292
# mean squared error :  2.105895465090305
# root mean squared error : 1.4511703776918494
# Difference :
# Diffrence between cross val score and r2 score is : 0.40
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')
# Scores :
# r2 score: 0.8671859714559536
# Cross Val score : 0.5347023146433383
# Error :
# mean absolute error : 0.8510351773291953
# mean squared error :  1.313134440021105
# root mean squared error : 1.1459207826115665
# Difference :
# Diffrence between cross val score and r2 score is : 0.33
#
#
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# Scores :
# r2 score: 0.9138063770647993
# Cross Val score : 0.6679402417079616
# Error :
# mean absolute error : 0.6834401241351822
# mean squared error :  0.8521977386512953
# root mean squared error : 0.9231455674222215
# Difference :
# Diffrence between cross val score and r2 score is : 0.25
#
#
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=None)
# Scores :
# r2 score: 0.7709243078806307
# Cross Val score : 0.6488855472978374
# Error :
# mean absolute error : 1.2141950956693284
# mean squared error :  2.2648750586904702
# root mean squared error : 1.5049501847870148
# Difference :
# Diffrence between cross val score and r2 score is : 0.12
#
#
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
# Scores :
# r2 score: 0.8649937649673869
# Cross Val score : 0.6930962820277033
# Error :
# mean absolute error : 0.8878051100453745
# mean squared error :  1.3348088208928508
# root mean squared error : 1.1553392665762083
# Difference :
# Diffrence between cross val score and r2 score is : 0.17

# %%
#lets check the least diference between cross val score and r2 score for each model
least_difference_1
# Out:
# [(LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#   'Diffrence between cross val score and r2 score error is : 0.12'),
#  (SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#       kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#   'Diffrence between cross val score and r2 score error is : 0.23'),
#  (DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#   'Diffrence between cross val score and r2 score error is : 0.40'),
#  (KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                       weights='uniform'),
#   'Diffrence between cross val score and r2 score error is : 0.33'),
#  (RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         max_samples=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         n_estimators=100, n_jobs=None, oob_score=False,
#                         random_state=None, verbose=0, warm_start=False),
#   'Diffrence between cross val score and r2 score error is : 0.25'),
#  (AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                     n_estimators=50, random_state=None),
#   'Diffrence between cross val score and r2 score error is : 0.12'),
#  (GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                             init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                             max_features=None, max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_impurity_split=None,
#                             min_samples_leaf=1, min_samples_split=2,
#                             min_weight_fraction_leaf=0.0, n_estimators=100,
#                             n_iter_no_change=None, presort='deprecated',
#                             random_state=None, subsample=1.0, tol=0.0001,
#                             validation_fraction=0.1, verbose=0, warm_start=False),
#   'Diffrence between cross val score and r2 score error is : 0.17')]

# %% [markdown]
# observations :-
#
# we got AdaBoostRegressor for as best model for Y1(Next_Tmax) with less difference and high R2 score and less errors.

# %% [markdown]
# ## Best random state with Y2 (Next_Tmin)

# %%
max_r2score_2 = 0
rand_state_2 = 0
for j in range(1,200):
    x_train_2,x_test_2,y_train_2,y_test_2 = train_test_split(X,Y2,test_size=.22,random_state= j )
    lr = LinearRegression()
    lr.fit(x_train_2,y_train_2)
    pred_2 = lr.predict(x_test_2)
    r2_2 = r2_score(y_test_2,pred_2)
    if r2_2 > max_r2score_2:
        max_r2score_2 = r2_2
        rand_state_2 = j
print('Best r2 score is {} on random state {}'.format(max_r2score_2,rand_state_2))
# Out:
# Best r2 score is 0.8504714989399753 on random state 36

# %%
print('We got our best randoms sate as :',rand_state_2)
# Out:
# We got our best randoms sate as : 36

# %%
#Lets split for train and test data
x_train_2,x_test_2,y_train_2,y_test_2 = train_test_split(X,Y2,test_size=.22,random_state= rand_state_2)

# %% [markdown]
# ## Model Selection for Y2 (Next_Tmin)

# %%
#checking each model with Cross val score
models=[LinearRegression(),
        SVR(),
        DecisionTreeRegressor(),
        KNeighborsRegressor(),
        RandomForestRegressor(),
        AdaBoostRegressor(),
        GradientBoostingRegressor()]
least_difference_2 = []
for m in models:
    m.fit(x_train_2,y_train_2)
    pred_2 = m.predict(x_test_2)
    cvs = cross_val_score(m,X,Y2,cv =5)
    print('\n')
    print(m)
    print('Scores :')
    print('r2 score:',r2_score(y_test_2,pred_2))
    print('Cross Val score :',cvs.mean())
    print('Error :')
    print('mean absolute error :',mean_absolute_error(y_test_2,pred_2))
    print('mean squared error : ', mean_squared_error(y_test_2,pred_2))
    print('root mean squared error :',np.sqrt(mean_squared_error(y_test_2,pred_2)))
    print('Difference :')
    difference = np.abs(r2_score(y_test_2,pred_2) - cvs.mean())
    print('Diffrence between cross val score and r2 score is : {0:.2f}'.format(difference))
    least_difference_2.append((m,'Diffrence between cross val score and r2 score error is : {0:.2f}'.format(difference)))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Scores :
# r2 score: 0.8504714989399753
# Cross Val score : 0.771953550658074
# Error :
# mean absolute error : 0.7539651107787801
# mean squared error :  0.9420728445380582
# root mean squared error : 0.9706043707598159
# Difference :
# Diffrence between cross val score and r2 score is : 0.08
#
#
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# Scores :
# r2 score: 0.9209973164689097
# Cross Val score : 0.7239564250642474
# Error :
# mean absolute error : 0.5455292328234553
# mean squared error :  0.4977397771840001
# root mean squared error : 0.7055067520470659
# Difference :
# Diffrence between cross val score and r2 score is : 0.20
#
#
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')
# Scores :
# r2 score: 0.8131875439926677
# Cross Val score : 0.44524354232662977
# Error :
# mean absolute error : 0.8098722698326835
# mean squared error :  1.176972554251186
# root mean squared error : 1.0848836593161435
# Difference :
# Diffrence between cross val score and r2 score is : 0.37
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')
# Scores :
# r2 score: 0.8813230260788775
# Cross Val score : 0.6007258783293491
# Error :
# mean absolute error : 0.6717926357847185
# mean squared error :  0.7476992921781546
# root mean squared error : 0.864696069251014
# Difference :
# Diffrence between cross val score and r2 score is : 0.28
#
#
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# Scores :
# r2 score: 0.9188233110745827
# Cross Val score : 0.7353180527889879
# Error :
# mean absolute error : 0.5406406177908112
# mean squared error :  0.5114366405335007
# root mean squared error : 0.7151479850586875
# Difference :
# Diffrence between cross val score and r2 score is : 0.18
#
#
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=None)
# Scores :
# r2 score: 0.8113869662878154
# Cross Val score : 0.7267583886574804
# Error :
# mean absolute error : 0.8785195601121208
# mean squared error :  1.1883167150512806
# root mean squared error : 1.0900994060411557
# Difference :
# Diffrence between cross val score and r2 score is : 0.08
#
#
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
# Scores :
# r2 score: 0.9038813593660302
# Cross Val score : 0.780964116236462
# Error :
# mean absolute error : 0.6115304817177492
# mean squared error :  0.6055752619283318
# root mean squared error : 0.7781871638162196
# Difference :
# Diffrence between cross val score and r2 score is : 0.12

# %%
#lets check the least diference between cross val score and r2 score for each model
least_difference_2
# Out:
# [(LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#   'Diffrence between cross val score and r2 score error is : 0.08'),
#  (SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#       kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#   'Diffrence between cross val score and r2 score error is : 0.20'),
#  (DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#   'Diffrence between cross val score and r2 score error is : 0.37'),
#  (KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                       weights='uniform'),
#   'Diffrence between cross val score and r2 score error is : 0.28'),
#  (RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         max_samples=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         n_estimators=100, n_jobs=None, oob_score=False,
#                         random_state=None, verbose=0, warm_start=False),
#   'Diffrence between cross val score and r2 score error is : 0.18'),
#  (AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                     n_estimators=50, random_state=None),
#   'Diffrence between cross val score and r2 score error is : 0.08'),
#  (GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                             init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                             max_features=None, max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_impurity_split=None,
#                             min_samples_leaf=1, min_samples_split=2,
#                             min_weight_fraction_leaf=0.0, n_estimators=100,
#                             n_iter_no_change=None, presort='deprecated',
#                             random_state=None, subsample=1.0, tol=0.0001,
#                             validation_fraction=0.1, verbose=0, warm_start=False),
#   'Diffrence between cross val score and r2 score error is : 0.12')]

# %% [markdown]
# ## Hyperparmeter Tuning for both the models

# %% [markdown]
# 1. Hyperparamter Tuning for Y1 (Next_Tmax) :- AdaBoostRegressor

# %% [markdown]
# **since we choose AdaBoostRegressor for Y1(Next_Tmax), lets perform hyperparameter tuning**

# %%
#lets create the parameter list to pass in Randomised serach cv
parameters = {'n_estimators' : list(range(50,251,50)), 'loss' : ['linear', 'square', 'exponential']}
#using randomised search CV
gsvada = RandomizedSearchCV(AdaBoostRegressor() , param_distributions= parameters,cv =5)
gsvada.fit(x_train_2,y_train_2) 
print(gsvada.best_score_)
print(gsvada.best_params_)
# Out:
# 0.8061152902589699
# {'n_estimators': 250, 'loss': 'square'}

# %% [markdown]
# ## 2.Hyperparamter Tuning for Y2 (Next_Tmin) : LinearRegression

# %% [markdown]
# **since we choose LinearRegression for Y2(Next_Tmin), lets perform hyperparameter tuning**

# %%
#lets create the parameter list to pass in Randomised seracgh cv
parameters = {'fit_intercept' : [True, False], 'normalize' : [True, False],'n_jobs':list(range(50,251,50))}
#using randomised search CV
gsvlr = RandomizedSearchCV(LinearRegression() , param_distributions= parameters,cv =5)
gsvlr.fit(x_train_1,y_train_1) 
print(gsvlr.best_score_)
print(gsvlr.best_params_)
# Out:
# 0.753144525529646
# {'normalize': False, 'n_jobs': 50, 'fit_intercept': True}

# %% [markdown]
# ## Creating a Final Model for Y1 and Y2

# %% [markdown]
# **1.Final Model for Y1 (Next_Tmax) : AdaBoostRegressor**

# %%
#Lets use our best parameters obtained from hyperparameter tuning
gsvada.best_params_
# Out:
# {'loss': 'square', 'n_estimators': 250}

# %%
#since we got knn as our best model for y1(Next_Tmax)
#This model is not overfitting
#lets create our final model

final_ab1_y1 = AdaBoostRegressor(n_estimators = 200,loss='square' )
final_ab1_y1.fit(x_train_1,y_train_1)
final_pred_y1 = final_ab1_y1.predict(x_test_1)
cvs_1 = cross_val_score(final_ab1_y1,X,Y1,cv =5)
print('\n')
print('Scores :')
print('r2 score:',r2_score(y_test_1,final_pred_y1))
print('Cross Val score :',cvs_1.mean())
print('\n')
print('Error :')
print('mean absolute error :',mean_absolute_error(y_test_1,final_pred_y1))
print('mean squared error : ', mean_squared_error(y_test_1,final_pred_y1))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test_1,final_pred_y1)))
print('\n')
print('Difference :')
difference_1 = np.abs(r2_score(y_test_1,final_pred_y1) - cvs_1.mean())
print('Diffrence between cross val score and r2 score is : {0:.2f}'.format(difference_1))
# Out:
# Scores :
# r2 score: 0.7863176790089159
# Cross Val score : 0.6528247233869295
#
#
# Error :
# mean absolute error : 1.173348647357723
# mean squared error :  2.112680550337956
# root mean squared error : 1.4535062952522622
#
#
# Difference :
# Diffrence between cross val score and r2 score is : 0.13

# %% [markdown]
# ## 2.Final Model for Y2 (Next_Tmin) : LinearRegression

# %%
#since we got knn as our best model for y1(Next_Tmax)
#This model is not overfitting
#lets create our final model

final_ada_y2 = LinearRegression(normalize=True, n_jobs= 100, fit_intercept= True)
final_ada_y2.fit(x_train_2,y_train_2)
final_pred_y2 = final_ada_y2.predict(x_test_2)
cvs_2 = cross_val_score(final_ada_y2,X,Y2,cv =5)
print('\n')
print('Scores :')
print('r2 score:',r2_score(y_test_2,final_pred_y2))
print('Cross Val score :',cvs_2.mean())
print('\n')
print('Error :')
print('mean absolute error :',mean_absolute_error(y_test_2,final_pred_y2))
print('mean squared error : ', mean_squared_error(y_test_2,final_pred_y2))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test_2,final_pred_y2)))
print('\n')
print('Difference :')
difference_2 = np.abs(r2_score(y_test_2,final_pred_y2) - cvs_2.mean())
print('Diffrence between cross val score and r2 score is : {0:.2f}'.format(difference_2))
# Out:
# Scores :
# r2 score: 0.8504714989399751
# Cross Val score : 0.7719535506580739
#
#
# Error :
# mean absolute error : 0.7539651107787808
# mean squared error :  0.9420728445380597
# root mean squared error : 0.9706043707598168
#
#
# Difference :
# Diffrence between cross val score and r2 score is : 0.08

# %% [markdown]
# **we got our final model for Next_Tmin (y2) with 85 % accuracy and less overfitting compare to all the models.**

# %% [markdown]
# ## Saving the Y1(Next_Tmax) Model

# %%
#serialization using joblib
import joblib
joblib.dump(final_ab1_y1,'Temperature_Max.obj')
# Out:
# ['Temperature_Max.obj']

# %%
Temperature_Max = joblib.load('Temperature_Max.obj')

# %%
#lets predict using our obj file
max_temp_pred = Temperature_Max.predict(x_test_1)

# %%
#lets check out the score, to verify
r2_score(y_test_1,max_temp_pred)
# Out:
# 0.7863176790089159

# %% [markdown]
# ## Saving the Y2(Next_Tmin) Model

# %%
#serialization using joblib
import joblib
joblib.dump(final_ada_y2,'Temperature_Min.obj')
# Out:
# ['Temperature_Min.obj']

# %%
Temperature_Min = joblib.load('Temperature_Min.obj')

# %%
#lets predict using our obj file
min_temp_pred = Temperature_Min.predict(x_test_2)

# %%
#lets check out the score, to verify
r2_score(y_test_2,min_temp_pred)
# Out:
# 0.8504714989399751

# %% [markdown]
# ## Plotting y_test vs predicted

# %% [markdown]
# **Y1 (Next_Tmax)**

# %%
#lets plot y_test vs predicted 

plt.figure(figsize=(6,4))
plt.scatter(x = y_test_1,y = max_temp_pred,color = 'r')
plt.plot(y_test_1,y_test_1,color = 'b')
plt.xlabel('Actual charges')
plt.ylabel('Predicted charges')
plt.title('KNN Regressor : Y1 (max_tempearature)')
plt.show()

# %% [markdown]
# **Y2 (Next_Tmin)**

# %%
#lets plot y_test vs predicted 

plt.figure(figsize=(6,4))
plt.scatter(x = y_test_2,y = min_temp_pred,color = 'r')
plt.plot(y_test_2,y_test_2,color = 'b')
plt.xlabel('Actual charges')
plt.ylabel('Predicted charges')
plt.title('ADAboost Regressor : Y2 (max_tempearature)')
# Out:
# Text(0.5, 1.0, 'ADAboost Regressor : Y2 (max_tempearature)')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Y1 (Next_Tmax)**

# %%
#lets make a dataframe of actual answers vs predicted answers
conclusion1 = pd.DataFrame((Temperature_Max.predict(x_test_1)[:],y_test_1[:]),index= ['Predicted','Actual'])
conclusion1
# Out:
#                 0          1          2          3          4          5     \
# Predicted  34.190078  26.907155  26.327043  27.774429  32.303846  33.856877
# Actual     35.400000  29.500000  26.800000  26.800000  34.000000  36.200000
#
#                 6          7          8          9         10         11    \
# Predicted  27.525569  27.569621  31.263628  26.975528  29.95775  32.089415
# Actual     27.900000  24.400000  33.900000  25.800000  31.10000  32.100000
#
#                 12        13         14         15         16         17    \
# Predicted  31.870915  25.83593  30.504074  29.389809  29.699637  32.389733
# Actual     33.900000  22.60000  30.274887  29.300000  31.700000  32.700000
#
#                 18         19         20         21         22         23    \
# Predicted  29.788876  28.779702  31.892203  33.835511  30.885156  33.182979
# Actual     29.400000  27.000000  32.300000  35.100000  30.500000  32.600000
#
#                 24         25         26         27         28         29    \
# Predicted  26.387424  34.868396  28.451257  30.356813  29.065459  29.472655
# Actual     24.900000  35.900000  27.300000  32.200000  28.400000  31.100000
#
#                 30         31         32         33         34         35    \
# Predicted  31.050725  27.302077  28.765202  30.885156  31.668663  32.677409
# Actual     32.100000  27.900000  27.200000  30.300000  30.900000  31.300000
#
#                 36         37         38         39         40         41    \
# Predicted  33.433923  29.620114  33.696603  29.862031  29.308423  26.546211
# Actual     31.800000  30.900000  33.300000  30.500000  29.700000  24.700000
#
#                 42         43         44         45         46         47    \
# Predicted  28.546752  26.501221  30.531702  32.250943  33.586674  31.627492
# Actual     27.000000  27.200000  31.000000  33.100000  33.400000  32.700000
#
#                 48         49         50        51         52         53    \
# Predicted  31.096605  29.862031  29.689424  32.31349  26.071894  27.825179
# Actual     29.400000  30.300000  27.100000  30.60000  25.900000  26.700000
#
#                 54         55         56         57         58         59    \
# Predicted  25.379533  30.724724  28.980303  33.553083  30.939001  28.925209
# Actual     23.100000  29.000000  28.600000  32.000000  31.100000  28.900000
#
#                 60         61         62         63         64         65    \
# Predicted  32.895726  28.468274  30.356813  26.296034  30.531702  27.212928
# Actual     31.600000  28.900000  30.500000  23.800000  30.600000  26.800000
